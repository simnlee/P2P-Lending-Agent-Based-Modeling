# %% [markdown]
# # Create Agents

# %%
from mesa import Agent
import random

class BorrowerAgent(Agent):
    def __init__(self, model, collateral, borrow_amount):
        super().__init__(model)
        self.collateral = collateral  # Amount of collateral provided
        self.borrow_amount = borrow_amount  # Amount the agent wants to borrow
        self.debt = 0  # Current outstanding debt

    def step(self):
        # Simulate borrowing behavior
        if self.debt == 0 or self.collateral > 0:
            self.borrow()

        # Simulate repaying behavior
        if self.debt > 0 and random.random() < 0.5:  # 50% chance of repaying some debt
            self.repay()

    def borrow(self):
        """Attempt to borrow based on risk tolerance and collateral."""
        max_borrow = self.collateral * self.model.loan_to_value_ratio
        if self.borrow_amount <= max_borrow and self.borrow_amount > 0:
            self.debt += self.borrow_amount
            self.model.total_borrowed += self.borrow_amount
            print(f"Borrower {self.unique_id} borrowed {self.borrow_amount}")

    def repay(self):
        """Repay a portion of the debt."""
        repayment = min(self.debt, random.uniform(0.1, 0.3) * self.debt)  # Repay 10-30% of debt
        self.debt -= repayment
        self.model.total_borrowed -= repayment
        print(f"Borrower {self.unique_id} repaid {repayment}, remaining debt: {self.debt}")


class LenderAgent(Agent):
    def __init__(self, model, liquidity):
        super().__init__(model)
        self.liquidity = liquidity  # Amount of funds available to lend

    def step(self):
        # Simulate lending behavior
        self.supply_liquidity()

    def supply_liquidity(self):
        """Supply liquidity to the AAVE protocol."""
        if self.liquidity > 0:
            self.model.total_liquidity += self.liquidity
            print(f"Lender {self.unique_id} supplied {self.liquidity}")
            self.liquidity = 0  # Assume full supply for simplicity
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from mesa import Agent
#       2 import random
#       4 class BorrowerAgent(Agent):
#
# File c:\Users\16158\OneDrive - PennO365\Desktop\P2P-Lending-Multi-Agent-Reinforcement-Learning\.conda\Lib\site-packages\mesa\__init__.py:9
#       6 import datetime
#       8 import mesa.experimental as experimental
# ----> 9 import mesa.space as space
#      10 from mesa.agent import Agent
#      11 from mesa.batchrunner import batch_run
#
# File c:\Users\16158\OneDrive - PennO365\Desktop\P2P-Lending-Multi-Agent-Reinforcement-Learning\.conda\Lib\site-packages\mesa\space.py:40
#      37 from warnings import warn
#      39 with contextlib.suppress(ImportError):
# ---> 40     import networkx as nx
#      42 import numpy as np
#      43 import numpy.typing as npt
#
# File c:\Users\16158\OneDrive - PennO365\Desktop\P2P-Lending-Multi-Agent-Reinforcement-Learning\.conda\Lib\site-packages\networkx\__init__.py:46
#      43 from networkx.readwrite import *
#      45 # Need to test with SciPy, when available
# ---> 46 from networkx import algorithms
#      47 from networkx.algorithms import *
#      49 from networkx import linalg
#
# File c:\Users\16158\OneDrive - PennO365\Desktop\P2P-Lending-Multi-Agent-Reinforcement-Learning\.conda\Lib\site-packages\networkx\algorithms\__init__.py:13
#      11 from networkx.algorithms.communicability_alg import *
#      12 from networkx.algorithms.components import *
# ---> 13 from networkx.algorithms.coloring import *
#      14 from networkx.algorithms.core import *
#      15 from networkx.algorithms.covering import *
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1138, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:1078, in _find_spec(name, path, target)
#
# File <frozen importlib._bootstrap_external>:1507, in find_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1479, in _get_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1634, in find_spec(self, fullname, target)
#
# KeyboardInterrupt:

# %%
from mesa import Model
from mesa.datacollection import DataCollector
import random

class AAVEModel(Model):
    def __init__(self, num_borrowers, num_lenders, collateral, borrow_amount, initial_liquidity, loan_to_value_ratio, liquidation_threshold, liquidation_bonus, base_rate, rate_slope):
        super().__init__()
        self.steps = 0  # Internal step counter
        self.total_liquidity = initial_liquidity  # Total liquidity in the lending pool
        self.total_borrowed = 0  # Total borrowed funds
        self.loan_to_value_ratio = loan_to_value_ratio  # LTV ratio (e.g., 0.75)
        self.liquidation_threshold = liquidation_threshold  # Threshold for liquidation (e.g., 0.85)
        self.liquidation_bonus = liquidation_bonus  # Bonus for liquidators (e.g., 0.1)
        self.base_rate = base_rate  # Base interest rate (e.g., 0.02 for 2%)
        self.rate_slope = rate_slope  # Slope for utilization-based rate changes

        # Create agents
        BorrowerAgent.create_agents(model=self, collateral=collateral, borrow_amount=borrow_amount, n=num_borrowers)
        LenderAgent.create_agents(model=self, liquidity=initial_liquidity, n=num_lenders)

        # Data collection
        self.datacollector = DataCollector(
            model_reporters={
                "Total Liquidity": lambda m: m.total_liquidity,
                "Total Borrowed": lambda m: m.total_borrowed,
                "Utilization Rate": lambda m: m.total_borrowed / m.total_liquidity,
                "Interest Rate": lambda m: m.calculate_interest_rate()
            }
        )

    def step(self):
        """Advance the model by one step."""
        self.steps += 1
        self.datacollector.collect(self)
        # First activate all sheep, then all wolves, both in random order
        self.agents_by_type[BorrowerAgent].shuffle_do("step")
        self.agents_by_type[LenderAgent].shuffle_do("step")

        # Check for liquidations after agents act
        self.check_liquidations()

    def calculate_interest_rate(self):
        """Calculate dynamic interest rate based on utilization."""
        if self.total_liquidity == 0:
            return self.base_rate  # Prevent division by zero
        utilization = self.total_borrowed / self.total_liquidity
        return self.base_rate + (self.rate_slope * utilization)

    def check_liquidations(self):
        """Liquidate borrowers who exceed the liquidation threshold."""
        for borrower in self.agents_by_type[BorrowerAgent]:
            if borrower.debt > borrower.collateral * self.liquidation_threshold:
                self.liquidate(borrower)

    def liquidate(self, borrower):
        """Seize a portion of collateral and repay some of the debt."""
        seized_collateral = borrower.collateral * (1 + self.liquidation_bonus)
        repayment = min(seized_collateral, borrower.debt)
        
        borrower.debt -= repayment
        borrower.collateral -= seized_collateral  # Collateral is reduced
        self.total_liquidity += repayment  # Repaid amount is added back to liquidity
        self.total_borrowed -= repayment  # Reduce total borrowed amount

        print(f"Borrower {borrower.unique_id} was liquidated! Seized {seized_collateral} collateral, repaid {repayment} debt.")

# %%
model = AAVEModel(num_borrowers=20, 
                  num_lenders=15, 
                  collateral=100, 
                  borrow_amount=50, 
                  initial_liquidity=1000, 
                  loan_to_value_ratio=0.75, 
                  liquidation_threshold=0.85, 
                  liquidation_bonus=0.1, 
                  base_rate=0.02, 
                  rate_slope=0.01)

# %%
for i in range(30):
    model.step()
# Out:
# Borrower 2 borrowed 50
# Borrower 2 repaid 5.570884431131475, remaining debt: 44.429115568868525
# Borrower 9 borrowed 50
# Borrower 9 repaid 6.272823650361993, remaining debt: 43.72717634963801
# Borrower 17 borrowed 50
# Borrower 17 repaid 11.820730080918846, remaining debt: 38.17926991908115
# Borrower 5 borrowed 50
# Borrower 8 borrowed 50
# Borrower 18 borrowed 50
# Borrower 18 repaid 10.58639169064644, remaining debt: 39.41360830935356
# Borrower 1 borrowed 50
# Borrower 1 repaid 6.5472288190757215, remaining debt: 43.45277118092428
# Borrower 19 borrowed 50
# Borrower 19 repaid 12.144373132930381, remaining debt: 37.85562686706962
# Borrower 3 borrowed 50
# Borrower 6 borrowed 50
# Borrower 6 repaid 5.078434011560195, remaining debt: 44.9215659884398
# Borrower 20 borrowed 50
# Borrower 11 borrowed 50
# Borrower 10 borrowed 50
# Borrower 16 borrowed 50
# Borrower 16 repaid 7.961377941543956, remaining debt: 42.03862205845604
# Borrower 4 borrowed 50
# Borrower 14 borrowed 50
# Borrower 12 borrowed 50
# Borrower 12 repaid 9.986498698544352, remaining debt: 40.01350130145565
# Borrower 15 borrowed 50
# Borrower 15 repaid 7.109667809973201, remaining debt: 42.8903321900268
# Borrower 13 borrowed 50
# Borrower 13 repaid 12.066162511809676, remaining debt: 37.93383748819032
# Borrower 7 borrowed 50
# Borrower 7 repaid 9.536315839058357, remaining debt: 40.46368416094164
# Lender 33 supplied 1000
# Lender 21 supplied 1000
# Lender 22 supplied 1000
# Lender 32 supplied 1000
# Lender 35 supplied 1000
# Lender 31 supplied 1000
# Lender 30 supplied 1000
# Lender 25 supplied 1000
# Lender 23 supplied 1000
# Lender 26 supplied 1000
# Lender 27 supplied 1000
# Lender 28 supplied 1000
# Lender 24 supplied 1000
# Lender 34 supplied 1000
# Lender 29 supplied 1000
# Borrower 9 borrowed 50
# Borrower 9 repaid 23.138003506340215, remaining debt: 70.58917284329779
# Borrower 16 borrowed 50
# Borrower 16 repaid 21.02427338257421, remaining debt: 71.01434867588183
# Borrower 10 borrowed 50
# Borrower 10 repaid 11.018015127985322, remaining debt: 88.98198487201468
# Borrower 18 borrowed 50
# Borrower 18 repaid 24.482925343676044, remaining debt: 64.93068296567752
# Borrower 7 borrowed 50
# Borrower 7 repaid 19.412583763842377, remaining debt: 71.05110039709926
# Borrower 14 borrowed 50
# Borrower 5 borrowed 50
# Borrower 5 repaid 28.427732400027455, remaining debt: 71.57226759997255
# Borrower 1 borrowed 50
# Borrower 1 repaid 13.007714601924897, remaining debt: 80.44505657899938
# Borrower 2 borrowed 50
# Borrower 2 repaid 10.60737198567059, remaining debt: 83.82174358319793
# Borrower 20 borrowed 50
# Borrower 20 repaid 28.314415281875615, remaining debt: 71.68558471812439
# Borrower 11 borrowed 50
# Borrower 13 borrowed 50
# Borrower 13 repaid 11.967657953769862, remaining debt: 75.96617953442046
# Borrower 3 borrowed 50
# Borrower 3 repaid 14.49266891281335, remaining debt: 85.50733108718666
# Borrower 17 borrowed 50
# Borrower 17 repaid 20.861875999393348, remaining debt: 67.3173939196878
# Borrower 19 borrowed 50
# Borrower 15 borrowed 50
# Borrower 12 borrowed 50
# Borrower 4 borrowed 50
# Borrower 4 repaid 24.654859226863927, remaining debt: 75.34514077313608
# Borrower 6 borrowed 50
# Borrower 6 repaid 16.24143017877604, remaining debt: 78.68013580966375
# Borrower 8 borrowed 50
# Borrower 3 was liquidated! Seized 110.00000000000001 collateral, repaid 85.50733108718666 debt.
# Borrower 8 was liquidated! Seized 110.00000000000001 collateral, repaid 100 debt.
# Borrower 10 was liquidated! Seized 110.00000000000001 collateral, repaid 88.98198487201468 debt.
# Borrower 11 was liquidated! Seized 110.00000000000001 collateral, repaid 100 debt.
# Borrower 12 was liquidated! Seized 110.00000000000001 collateral, repaid 90.01350130145565 debt.
# Borrower 14 was liquidated! Seized 110.00000000000001 collateral, repaid 100 debt.
# Borrower 15 was liquidated! Seized 110.00000000000001 collateral, repaid 92.8903321900268 debt.
# Borrower 19 was liquidated! Seized 110.00000000000001 collateral, repaid 87.85562686706962 debt.
# Borrower 9 borrowed 50
# Borrower 2 borrowed 50
# Borrower 2 repaid 17.516650732646752, remaining debt: 116.30509285055118
# Borrower 1 borrowed 50
# Borrower 1 repaid 17.128481101546253, remaining debt: 113.31657547745313
# Borrower 4 borrowed 50
# Borrower 4 repaid 37.0334082611796, remaining debt: 88.31173251195648
# Borrower 18 borrowed 50
# Borrower 5 borrowed 50
# Borrower 7 borrowed 50
# Borrower 16 borrowed 50
# Borrower 16 repaid 24.78536924460124, remaining debt: 96.22897943128059
# Borrower 17 borrowed 50
# Borrower 17 repaid 26.64408570258702, remaining debt: 90.67330821710078
# Borrower 13 borrowed 50
# Borrower 20 borrowed 50
# Borrower 6 borrowed 50
# Borrower 1 was liquidated! Seized 110.00000000000001 collateral, repaid 110.00000000000001 debt.
# Borrower 2 was liquidated! Seized 110.00000000000001 collateral, repaid 110.00000000000001 debt.
# Borrower 3 was liquidated! Seized -11.000000000000016 collateral, repaid -11.000000000000016 debt.
# Borrower 4 was liquidated! Seized 110.00000000000001 collateral, repaid 88.31173251195648 debt.
# Borrower 5 was liquidated! Seized 110.00000000000001 collateral, repaid 110.00000000000001 debt.
# Borrower 6 was liquidated! Seized 110.00000000000001 collateral, repaid 110.00000000000001 debt.
# Borrower 7 was liquidated! Seized 110.00000000000001 collateral, repaid 110.00000000000001 debt.
# Borrower 8 was liquidated! Seized -11.000000000000016 collateral, repaid -11.000000000000016 debt.
# Borrower 9 was liquidated! Seized 110.00000000000001 collateral, repaid 110.00000000000001 debt.
# Borrower 10 was liquidated! Seized -11.000000000000016 collateral, repaid -11.000000000000016 debt.
# Borrower 11 was liquidated! Seized -11.000000000000016 collateral, repaid -11.000000000000016 debt.
# Borrower 12 was liquidated! Seized -11.000000000000016 collateral, repaid -11.000000000000016 debt.
# Borrower 13 was liquidated! Seized 110.00000000000001 collateral, repaid 110.00000000000001 debt.
# Borrower 14 was liquidated! Seized -11.000000000000016 collateral, repaid -11.000000000000016 debt.
# Borrower 15 was liquidated! Seized -11.000000000000016 collateral, repaid -11.000000000000016 debt.
# Borrower 16 was liquidated! Seized 110.00000000000001 collateral, repaid 96.22897943128059 debt.
# Borrower 17 was liquidated! Seized 110.00000000000001 collateral, repaid 90.67330821710078 debt.
# Borrower 18 was liquidated! Seized 110.00000000000001 collateral, repaid 110.00000000000001 debt.
# Borrower 19 was liquidated! Seized -11.000000000000016 collateral, repaid -11.000000000000016 debt.
# Borrower 20 was liquidated! Seized 110.00000000000001 collateral, repaid 110.00000000000001 debt.
# Borrower 3 repaid 2.72925763918205, remaining debt: 8.270742360817966
# Borrower 13 repaid 1.845541786404581, remaining debt: 14.120637748015866
# Borrower 14 repaid 2.436475651830972, remaining debt: 8.563524348169043
# Borrower 12 repaid 2.629487050220832, remaining debt: 8.370512949779183
# Borrower 6 repaid 1.9234123284455142, remaining debt: 16.75672348121821
# Borrower 11 repaid 2.0237054391494733, remaining debt: 8.976294560850542
# Borrower 1 repaid 0.7716658238943738, remaining debt: 2.54490965355874
# Borrower 9 repaid 3.1515660564641306, remaining debt: 7.437606786833644
# Borrower 8 repaid 3.1002597719453013, remaining debt: 7.899740228054714
# Borrower 15 repaid 2.0799589443182467, remaining debt: 8.92004105568177
# Borrower 5 repaid 2.2834029936215243, remaining debt: 9.288864606351009
# Borrower 18 repaid 1.2973823322899518, remaining debt: 3.6333006333875533
# Borrower 20 repaid 2.3099382166814415, remaining debt: 9.375646501442933
# Borrower 1 was liquidated! Seized -11.000000000000016 collateral, repaid -11.000000000000016 debt.
# Borrower 2 was liquidated! Seized -11.000000000000016 collateral, repaid -11.000000000000016 debt.
# Borrower 3 was liquidated! Seized 1.100000000000002 collateral, repaid 1.100000000000002 debt.
# Borrower 4 was liquidated! Seized -11.000000000000016 collateral, repaid -11.000000000000016 debt.
# Borrower 5 was liquidated! Seized -11.000000000000016 collateral, repaid -11.000000000000016 debt.
# Borrower 6 was liquidated! Seized -11.000000000000016 collateral, repaid -11.000000000000016 debt.
# Borrower 7 was liquidated! Seized -11.000000000000016 collateral, repaid -11.000000000000016 debt.
# Borrower 8 was liquidated! Seized 1.100000000000002 collateral, repaid 1.100000000000002 debt.
# Borrower 9 was liquidated! Seized -11.000000000000016 collateral, repaid -11.000000000000016 debt.
# Borrower 10 was liquidated! Seized 1.100000000000002 collateral, repaid 1.100000000000002 debt.
# Borrower 11 was liquidated! Seized 1.100000000000002 collateral, repaid 1.100000000000002 debt.
# Borrower 12 was liquidated! Seized 1.100000000000002 collateral, repaid 1.100000000000002 debt.
# Borrower 13 was liquidated! Seized -11.000000000000016 collateral, repaid -11.000000000000016 debt.
# Borrower 14 was liquidated! Seized 1.100000000000002 collateral, repaid 1.100000000000002 debt.
# Borrower 15 was liquidated! Seized 1.100000000000002 collateral, repaid 1.100000000000002 debt.
# Borrower 16 was liquidated! Seized -11.000000000000016 collateral, repaid -11.000000000000016 debt.
# Borrower 17 was liquidated! Seized -11.000000000000016 collateral, repaid -11.000000000000016 debt.
# Borrower 18 was liquidated! Seized -11.000000000000016 collateral, repaid -11.000000000000016 debt.
# Borrower 19 was liquidated! Seized 1.100000000000002 collateral, repaid 1.100000000000002 debt.
# Borrower 20 was liquidated! Seized -11.000000000000016 collateral, repaid -11.000000000000016 debt.
# Borrower 18 repaid 3.1574123141208053, remaining debt: 11.475888319266765
# Borrower 3 repaid 1.841762720086019, remaining debt: 5.328979640731944
# Borrower 19 repaid 1.696338406779517, remaining debt: 8.203661593220497
# Borrower 16 repaid 2.930513058268288, remaining debt: 8.069486941731729
# Borrower 11 repaid 0.972758503532974, remaining debt: 6.903536057317566
# Borrower 17 repaid 3.1319826058963387, remaining debt: 7.868017394103678
# Borrower 10 repaid 2.953142525001903, remaining debt: 6.946857474998112
# Borrower 2 repaid 2.874814984230534, remaining debt: 14.430277866320642
# Borrower 20 repaid 4.472015739459007, remaining debt: 15.903630761983944
# Borrower 1 repaid 2.3248842340234286, remaining debt: 11.220025419535327
# Borrower 6 repaid 4.736832417807501, remaining debt: 23.01989106341072
# Borrower 1 was liquidated! Seized 1.100000000000002 collateral, repaid 1.100000000000002 debt.
# Borrower 2 was liquidated! Seized 1.100000000000002 collateral, repaid 1.100000000000002 debt.
# Borrower 3 was liquidated! Seized -0.11000000000000035 collateral, repaid -0.11000000000000035 debt.
# Borrower 4 was liquidated! Seized 1.100000000000002 collateral, repaid 1.100000000000002 debt.
# Borrower 5 was liquidated! Seized 1.100000000000002 collateral, repaid 1.100000000000002 debt.
# Borrower 6 was liquidated! Seized 1.100000000000002 collateral, repaid 1.100000000000002 debt.
# Borrower 7 was liquidated! Seized 1.100000000000002 collateral, repaid 1.100000000000002 debt.
# Borrower 8 was liquidated! Seized -0.11000000000000035 collateral, repaid -0.11000000000000035 debt.
# Borrower 9 was liquidated! Seized 1.100000000000002 collateral, repaid 1.100000000000002 debt.
# Borrower 10 was liquidated! Seized -0.11000000000000035 collateral, repaid -0.11000000000000035 debt.
# Borrower 11 was liquidated! Seized -0.11000000000000035 collateral, repaid -0.11000000000000035 debt.
# Borrower 12 was liquidated! Seized -0.11000000000000035 collateral, repaid -0.11000000000000035 debt.
# Borrower 13 was liquidated! Seized 1.100000000000002 collateral, repaid 1.100000000000002 debt.
# Borrower 14 was liquidated! Seized -0.11000000000000035 collateral, repaid -0.11000000000000035 debt.
# Borrower 15 was liquidated! Seized -0.11000000000000035 collateral, repaid -0.11000000000000035 debt.
# Borrower 16 was liquidated! Seized 1.100000000000002 collateral, repaid 1.100000000000002 debt.
# Borrower 17 was liquidated! Seized 1.100000000000002 collateral, repaid 1.100000000000002 debt.
# Borrower 18 was liquidated! Seized 1.100000000000002 collateral, repaid 1.100000000000002 debt.
# Borrower 19 was liquidated! Seized -0.11000000000000035 collateral, repaid -0.11000000000000035 debt.
# Borrower 20 was liquidated! Seized 1.100000000000002 collateral, repaid 1.100000000000002 debt.
# Borrower 18 repaid 2.775567865785909, remaining debt: 7.600320453480855
# Borrower 10 repaid 0.877410076270242, remaining debt: 6.17944739872787
# Borrower 1 repaid 2.9777709271129895, remaining debt: 7.142254492422336
# Borrower 8 repaid 0.859786242610153, remaining debt: 6.049953985444559
# Borrower 17 repaid 1.0640582486200056, remaining debt: 5.70395914548367
# Borrower 19 repaid 1.1851109647663949, remaining debt: 7.128550628454104
# Borrower 1 was liquidated! Seized -0.11000000000000035 collateral, repaid -0.11000000000000035 debt.
# Borrower 2 was liquidated! Seized -0.11000000000000035 collateral, repaid -0.11000000000000035 debt.
# Borrower 3 was liquidated! Seized 0.011000000000000041 collateral, repaid 0.011000000000000041 debt.
# Borrower 4 was liquidated! Seized -0.11000000000000035 collateral, repaid -0.11000000000000035 debt.
# Borrower 5 was liquidated! Seized -0.11000000000000035 collateral, repaid -0.11000000000000035 debt.
# Borrower 6 was liquidated! Seized -0.11000000000000035 collateral, repaid -0.11000000000000035 debt.
# Borrower 7 was liquidated! Seized -0.11000000000000035 collateral, repaid -0.11000000000000035 debt.
# Borrower 8 was liquidated! Seized 0.011000000000000041 collateral, repaid 0.011000000000000041 debt.
# Borrower 9 was liquidated! Seized -0.11000000000000035 collateral, repaid -0.11000000000000035 debt.
# Borrower 10 was liquidated! Seized 0.011000000000000041 collateral, repaid 0.011000000000000041 debt.
# Borrower 11 was liquidated! Seized 0.011000000000000041 collateral, repaid 0.011000000000000041 debt.
# Borrower 12 was liquidated! Seized 0.011000000000000041 collateral, repaid 0.011000000000000041 debt.
# Borrower 13 was liquidated! Seized -0.11000000000000035 collateral, repaid -0.11000000000000035 debt.
# Borrower 14 was liquidated! Seized 0.011000000000000041 collateral, repaid 0.011000000000000041 debt.
# Borrower 15 was liquidated! Seized 0.011000000000000041 collateral, repaid 0.011000000000000041 debt.
# Borrower 16 was liquidated! Seized -0.11000000000000035 collateral, repaid -0.11000000000000035 debt.
# Borrower 17 was liquidated! Seized -0.11000000000000035 collateral, repaid -0.11000000000000035 debt.
# Borrower 18 was liquidated! Seized -0.11000000000000035 collateral, repaid -0.11000000000000035 debt.
# Borrower 19 was liquidated! Seized 0.011000000000000041 collateral, repaid 0.011000000000000041 debt.
# Borrower 20 was liquidated! Seized -0.11000000000000035 collateral, repaid -0.11000000000000035 debt.
# Borrower 3 repaid 1.3580307370387945, remaining debt: 4.06994890369315
# Borrower 4 repaid 1.0591642752939436, remaining debt: 8.950835724706073
# Borrower 6 repaid 6.414410423373754, remaining debt: 15.615480640036965
# Borrower 7 repaid 3.9584267492880314, remaining debt: 17.10267364781123
# Borrower 8 repaid 1.537449451439052, remaining debt: 4.501504534005507
# Borrower 14 repaid 2.1114629831769385, remaining debt: 5.4510613649921025
# Borrower 16 repaid 2.061799540536599, remaining debt: 5.017687401195127
# Borrower 9 repaid 3.244794446262963, remaining debt: 14.202812340570697
# Borrower 20 repaid 2.9102231438969697, remaining debt: 12.003407618086975
# Borrower 5 repaid 5.354080186356561, remaining debt: 13.944784419994463
# Borrower 11 repaid 1.9481992351090194, remaining debt: 5.054336822208547
# Borrower 18 repaid 1.217883485913314, remaining debt: 6.49243696756754
# Borrower 10 repaid 1.4298000629141647, remaining debt: 4.738647335813705
# Borrower 15 repaid 1.9617420950888278, remaining debt: 5.95729896059294
# Borrower 1 was liquidated! Seized 0.011000000000000041 collateral, repaid 0.011000000000000041 debt.
# Borrower 2 was liquidated! Seized 0.011000000000000041 collateral, repaid 0.011000000000000041 debt.
# Borrower 3 was liquidated! Seized -0.0011000000000000048 collateral, repaid -0.0011000000000000048 debt.
# Borrower 4 was liquidated! Seized 0.011000000000000041 collateral, repaid 0.011000000000000041 debt.
# Borrower 5 was liquidated! Seized 0.011000000000000041 collateral, repaid 0.011000000000000041 debt.
# Borrower 6 was liquidated! Seized 0.011000000000000041 collateral, repaid 0.011000000000000041 debt.
# Borrower 7 was liquidated! Seized 0.011000000000000041 collateral, repaid 0.011000000000000041 debt.
# Borrower 8 was liquidated! Seized -0.0011000000000000048 collateral, repaid -0.0011000000000000048 debt.
# Borrower 9 was liquidated! Seized 0.011000000000000041 collateral, repaid 0.011000000000000041 debt.
# Borrower 10 was liquidated! Seized -0.0011000000000000048 collateral, repaid -0.0011000000000000048 debt.
# Borrower 11 was liquidated! Seized -0.0011000000000000048 collateral, repaid -0.0011000000000000048 debt.
# Borrower 12 was liquidated! Seized -0.0011000000000000048 collateral, repaid -0.0011000000000000048 debt.
# Borrower 13 was liquidated! Seized 0.011000000000000041 collateral, repaid 0.011000000000000041 debt.
# Borrower 14 was liquidated! Seized -0.0011000000000000048 collateral, repaid -0.0011000000000000048 debt.
# Borrower 15 was liquidated! Seized -0.0011000000000000048 collateral, repaid -0.0011000000000000048 debt.
# Borrower 16 was liquidated! Seized 0.011000000000000041 collateral, repaid 0.011000000000000041 debt.
# Borrower 17 was liquidated! Seized 0.011000000000000041 collateral, repaid 0.011000000000000041 debt.
# Borrower 18 was liquidated! Seized 0.011000000000000041 collateral, repaid 0.011000000000000041 debt.
# Borrower 19 was liquidated! Seized -0.0011000000000000048 collateral, repaid -0.0011000000000000048 debt.
# Borrower 20 was liquidated! Seized 0.011000000000000041 collateral, repaid 0.011000000000000041 debt.
# Borrower 14 repaid 0.7082245581636532, remaining debt: 4.743936806828449
# Borrower 9 repaid 1.799941269706081, remaining debt: 12.391871070864617
# Borrower 16 repaid 1.3950169830247274, remaining debt: 3.6116704181704
# Borrower 18 repaid 1.2333992774488616, remaining debt: 5.248037690118679
# Borrower 19 repaid 0.8512416308081614, remaining debt: 6.267408997645942
# Borrower 12 repaid 1.1043296741831516, remaining debt: 6.266283275596029
# Borrower 8 repaid 0.6884896406237849, remaining debt: 3.8141148933817224
# Borrower 1 was liquidated! Seized -0.0011000000000000048 collateral, repaid -0.0011000000000000048 debt.
# Borrower 2 was liquidated! Seized -0.0011000000000000048 collateral, repaid -0.0011000000000000048 debt.
# Borrower 3 was liquidated! Seized 0.00011000000000000053 collateral, repaid 0.00011000000000000053 debt.
# Borrower 4 was liquidated! Seized -0.0011000000000000048 collateral, repaid -0.0011000000000000048 debt.
# Borrower 5 was liquidated! Seized -0.0011000000000000048 collateral, repaid -0.0011000000000000048 debt.
# Borrower 6 was liquidated! Seized -0.0011000000000000048 collateral, repaid -0.0011000000000000048 debt.
# Borrower 7 was liquidated! Seized -0.0011000000000000048 collateral, repaid -0.0011000000000000048 debt.
# Borrower 8 was liquidated! Seized 0.00011000000000000053 collateral, repaid 0.00011000000000000053 debt.
# Borrower 9 was liquidated! Seized -0.0011000000000000048 collateral, repaid -0.0011000000000000048 debt.
# Borrower 10 was liquidated! Seized 0.00011000000000000053 collateral, repaid 0.00011000000000000053 debt.
# Borrower 11 was liquidated! Seized 0.00011000000000000053 collateral, repaid 0.00011000000000000053 debt.
# Borrower 12 was liquidated! Seized 0.00011000000000000053 collateral, repaid 0.00011000000000000053 debt.
# Borrower 13 was liquidated! Seized -0.0011000000000000048 collateral, repaid -0.0011000000000000048 debt.
# Borrower 14 was liquidated! Seized 0.00011000000000000053 collateral, repaid 0.00011000000000000053 debt.
# Borrower 15 was liquidated! Seized 0.00011000000000000053 collateral, repaid 0.00011000000000000053 debt.
# Borrower 16 was liquidated! Seized -0.0011000000000000048 collateral, repaid -0.0011000000000000048 debt.
# Borrower 17 was liquidated! Seized -0.0011000000000000048 collateral, repaid -0.0011000000000000048 debt.
# Borrower 18 was liquidated! Seized -0.0011000000000000048 collateral, repaid -0.0011000000000000048 debt.
# Borrower 19 was liquidated! Seized 0.00011000000000000053 collateral, repaid 0.00011000000000000053 debt.
# Borrower 20 was liquidated! Seized -0.0011000000000000048 collateral, repaid -0.0011000000000000048 debt.
# Borrower 15 repaid 1.126311342085647, remaining debt: 4.831977618507293
# Borrower 20 repaid 2.9613196537087925, remaining debt: 9.032187964378181
# Borrower 6 repaid 2.747397525135015, remaining debt: 12.858183114901951
# Borrower 10 repaid 0.772928263416129, remaining debt: 3.9667090723975758
# Borrower 4 repaid 2.1389887360649924, remaining debt: 6.80194698864108
# Borrower 12 repaid 1.1117388775635118, remaining debt: 5.154434398032517
# Borrower 8 repaid 0.8537432379502663, remaining debt: 2.9602616554314563
# Borrower 13 repaid 3.3076689464545437, remaining debt: 20.813068801561336
# Borrower 7 repaid 3.1184301012003846, remaining debt: 13.974343546610847
# Borrower 19 repaid 1.0999899264672302, remaining debt: 5.167309071178712
# Borrower 18 repaid 0.5523133776980741, remaining debt: 4.696824312420604
# Borrower 14 repaid 1.27038903935793, remaining debt: 3.473437767470519
# Borrower 1 was liquidated! Seized 0.00011000000000000053 collateral, repaid 0.00011000000000000053 debt.
# Borrower 2 was liquidated! Seized 0.00011000000000000053 collateral, repaid 0.00011000000000000053 debt.
# Borrower 3 was liquidated! Seized -1.1000000000000059e-05 collateral, repaid -1.1000000000000059e-05 debt.
# Borrower 4 was liquidated! Seized 0.00011000000000000053 collateral, repaid 0.00011000000000000053 debt.
# Borrower 5 was liquidated! Seized 0.00011000000000000053 collateral, repaid 0.00011000000000000053 debt.
# Borrower 6 was liquidated! Seized 0.00011000000000000053 collateral, repaid 0.00011000000000000053 debt.
# Borrower 7 was liquidated! Seized 0.00011000000000000053 collateral, repaid 0.00011000000000000053 debt.
# Borrower 8 was liquidated! Seized -1.1000000000000059e-05 collateral, repaid -1.1000000000000059e-05 debt.
# Borrower 9 was liquidated! Seized 0.00011000000000000053 collateral, repaid 0.00011000000000000053 debt.
# Borrower 10 was liquidated! Seized -1.1000000000000059e-05 collateral, repaid -1.1000000000000059e-05 debt.
# Borrower 11 was liquidated! Seized -1.1000000000000059e-05 collateral, repaid -1.1000000000000059e-05 debt.
# Borrower 12 was liquidated! Seized -1.1000000000000059e-05 collateral, repaid -1.1000000000000059e-05 debt.
# Borrower 13 was liquidated! Seized 0.00011000000000000053 collateral, repaid 0.00011000000000000053 debt.
# Borrower 14 was liquidated! Seized -1.1000000000000059e-05 collateral, repaid -1.1000000000000059e-05 debt.
# Borrower 15 was liquidated! Seized -1.1000000000000059e-05 collateral, repaid -1.1000000000000059e-05 debt.
# Borrower 16 was liquidated! Seized 0.00011000000000000053 collateral, repaid 0.00011000000000000053 debt.
# Borrower 17 was liquidated! Seized 0.00011000000000000053 collateral, repaid 0.00011000000000000053 debt.
# Borrower 18 was liquidated! Seized 0.00011000000000000053 collateral, repaid 0.00011000000000000053 debt.
# Borrower 19 was liquidated! Seized -1.1000000000000059e-05 collateral, repaid -1.1000000000000059e-05 debt.
# Borrower 20 was liquidated! Seized 0.00011000000000000053 collateral, repaid 0.00011000000000000053 debt.
# Borrower 18 repaid 0.7621075506278464, remaining debt: 3.934606761792758
# Borrower 6 repaid 2.551162753449465, remaining debt: 10.306910361452488
# Borrower 17 repaid 1.2311384309433708, remaining debt: 4.572810714540299
# Borrower 9 repaid 1.3186200734062776, remaining debt: 11.07424099745834
# Borrower 12 repaid 1.3095515585553863, remaining debt: 3.844893839477131
# Borrower 10 repaid 0.5586304269097889, remaining debt: 3.408089645487787
# Borrower 15 repaid 1.1399766458918843, remaining debt: 3.692011972615408
# Borrower 13 repaid 2.617465613365344, remaining debt: 18.195493188195993
# Borrower 7 repaid 3.9606069138948534, remaining debt: 10.013626632715994
# Borrower 16 repaid 0.608966405149851, remaining debt: 3.003694013020549
# Borrower 19 repaid 1.4231735332008064, remaining debt: 3.7441465379779055
# Borrower 4 repaid 1.755923252517951, remaining debt: 5.045913736123129
# Borrower 1 was liquidated! Seized -1.1000000000000059e-05 collateral, repaid -1.1000000000000059e-05 debt.
# Borrower 2 was liquidated! Seized -1.1000000000000059e-05 collateral, repaid -1.1000000000000059e-05 debt.
# Borrower 3 was liquidated! Seized 1.1000000000000064e-06 collateral, repaid 1.1000000000000064e-06 debt.
# Borrower 4 was liquidated! Seized -1.1000000000000059e-05 collateral, repaid -1.1000000000000059e-05 debt.
# Borrower 5 was liquidated! Seized -1.1000000000000059e-05 collateral, repaid -1.1000000000000059e-05 debt.
# Borrower 6 was liquidated! Seized -1.1000000000000059e-05 collateral, repaid -1.1000000000000059e-05 debt.
# Borrower 7 was liquidated! Seized -1.1000000000000059e-05 collateral, repaid -1.1000000000000059e-05 debt.
# Borrower 8 was liquidated! Seized 1.1000000000000064e-06 collateral, repaid 1.1000000000000064e-06 debt.
# Borrower 9 was liquidated! Seized -1.1000000000000059e-05 collateral, repaid -1.1000000000000059e-05 debt.
# Borrower 10 was liquidated! Seized 1.1000000000000064e-06 collateral, repaid 1.1000000000000064e-06 debt.
# Borrower 11 was liquidated! Seized 1.1000000000000064e-06 collateral, repaid 1.1000000000000064e-06 debt.
# Borrower 12 was liquidated! Seized 1.1000000000000064e-06 collateral, repaid 1.1000000000000064e-06 debt.
# Borrower 13 was liquidated! Seized -1.1000000000000059e-05 collateral, repaid -1.1000000000000059e-05 debt.
# Borrower 14 was liquidated! Seized 1.1000000000000064e-06 collateral, repaid 1.1000000000000064e-06 debt.
# Borrower 15 was liquidated! Seized 1.1000000000000064e-06 collateral, repaid 1.1000000000000064e-06 debt.
# Borrower 16 was liquidated! Seized -1.1000000000000059e-05 collateral, repaid -1.1000000000000059e-05 debt.
# Borrower 17 was liquidated! Seized -1.1000000000000059e-05 collateral, repaid -1.1000000000000059e-05 debt.
# Borrower 18 was liquidated! Seized -1.1000000000000059e-05 collateral, repaid -1.1000000000000059e-05 debt.
# Borrower 19 was liquidated! Seized 1.1000000000000064e-06 collateral, repaid 1.1000000000000064e-06 debt.
# Borrower 20 was liquidated! Seized -1.1000000000000059e-05 collateral, repaid -1.1000000000000059e-05 debt.
# Borrower 12 repaid 1.0977793654748385, remaining debt: 2.7471133740022924
# Borrower 15 repaid 0.7976627540659038, remaining debt: 2.8943481185495044
# Borrower 5 repaid 2.5604183320314657, remaining debt: 11.374367087962998
# Borrower 11 repaid 0.9366733248290076, remaining debt: 4.118663397379539
# Borrower 16 repaid 0.7444131240057128, remaining debt: 2.259291889014836
# Borrower 20 repaid 2.0459692427310276, remaining debt: 6.986119721647155
# Borrower 1 repaid 0.962595551883582, remaining debt: 6.279659940538754
# Borrower 17 repaid 0.6391193387388924, remaining debt: 3.9337023758014067
# Borrower 8 repaid 0.6754251889446552, remaining debt: 2.2848463664868013
# Borrower 3 repaid 0.9124606557667733, remaining debt: 3.1584881479263758
# Borrower 13 repaid 2.453678002681278, remaining debt: 15.741826185514716
# Borrower 1 was liquidated! Seized 1.1000000000000064e-06 collateral, repaid 1.1000000000000064e-06 debt.
# Borrower 2 was liquidated! Seized 1.1000000000000064e-06 collateral, repaid 1.1000000000000064e-06 debt.
# Borrower 3 was liquidated! Seized -1.1000000000000081e-07 collateral, repaid -1.1000000000000081e-07 debt.
# Borrower 4 was liquidated! Seized 1.1000000000000064e-06 collateral, repaid 1.1000000000000064e-06 debt.
# Borrower 5 was liquidated! Seized 1.1000000000000064e-06 collateral, repaid 1.1000000000000064e-06 debt.
# Borrower 6 was liquidated! Seized 1.1000000000000064e-06 collateral, repaid 1.1000000000000064e-06 debt.
# Borrower 7 was liquidated! Seized 1.1000000000000064e-06 collateral, repaid 1.1000000000000064e-06 debt.
# Borrower 8 was liquidated! Seized -1.1000000000000081e-07 collateral, repaid -1.1000000000000081e-07 debt.
# Borrower 9 was liquidated! Seized 1.1000000000000064e-06 collateral, repaid 1.1000000000000064e-06 debt.
# Borrower 10 was liquidated! Seized -1.1000000000000081e-07 collateral, repaid -1.1000000000000081e-07 debt.
# Borrower 11 was liquidated! Seized -1.1000000000000081e-07 collateral, repaid -1.1000000000000081e-07 debt.
# Borrower 12 was liquidated! Seized -1.1000000000000081e-07 collateral, repaid -1.1000000000000081e-07 debt.
# Borrower 13 was liquidated! Seized 1.1000000000000064e-06 collateral, repaid 1.1000000000000064e-06 debt.
# Borrower 14 was liquidated! Seized -1.1000000000000081e-07 collateral, repaid -1.1000000000000081e-07 debt.
# Borrower 15 was liquidated! Seized -1.1000000000000081e-07 collateral, repaid -1.1000000000000081e-07 debt.
# Borrower 16 was liquidated! Seized 1.1000000000000064e-06 collateral, repaid 1.1000000000000064e-06 debt.
# Borrower 17 was liquidated! Seized 1.1000000000000064e-06 collateral, repaid 1.1000000000000064e-06 debt.
# Borrower 18 was liquidated! Seized 1.1000000000000064e-06 collateral, repaid 1.1000000000000064e-06 debt.
# Borrower 19 was liquidated! Seized -1.1000000000000081e-07 collateral, repaid -1.1000000000000081e-07 debt.
# Borrower 20 was liquidated! Seized 1.1000000000000064e-06 collateral, repaid 1.1000000000000064e-06 debt.
# Borrower 12 repaid 0.4618644391914468, remaining debt: 2.285249044810846
# Borrower 1 repaid 1.500316185083147, remaining debt: 4.779342655455607
# Borrower 20 repaid 1.1663224180567147, remaining debt: 5.81979620359044
# Borrower 17 repaid 0.953462977722221, remaining debt: 2.9802382980791857
# Borrower 19 repaid 0.6316508349683884, remaining debt: 3.1124947130095175
# Borrower 8 repaid 0.280289401838137, remaining debt: 2.0045570746486643
# Borrower 6 repaid 2.530111612714713, remaining debt: 7.776808648737775
# Borrower 2 repaid 3.610094934900222, remaining debt: 9.820182831420421
# Borrower 5 repaid 3.110630521891244, remaining debt: 8.263735466071754
# Borrower 18 repaid 0.7250595443574852, remaining debt: 3.209557117435273
# Borrower 9 repaid 2.0874468641828194, remaining debt: 8.98680403327552
# Borrower 15 repaid 0.5692080945423379, remaining debt: 2.3251401340071665
# Borrower 1 was liquidated! Seized -1.1000000000000081e-07 collateral, repaid -1.1000000000000081e-07 debt.
# Borrower 2 was liquidated! Seized -1.1000000000000081e-07 collateral, repaid -1.1000000000000081e-07 debt.
# Borrower 3 was liquidated! Seized 1.1000000000000085e-08 collateral, repaid 1.1000000000000085e-08 debt.
# Borrower 4 was liquidated! Seized -1.1000000000000081e-07 collateral, repaid -1.1000000000000081e-07 debt.
# Borrower 5 was liquidated! Seized -1.1000000000000081e-07 collateral, repaid -1.1000000000000081e-07 debt.
# Borrower 6 was liquidated! Seized -1.1000000000000081e-07 collateral, repaid -1.1000000000000081e-07 debt.
# Borrower 7 was liquidated! Seized -1.1000000000000081e-07 collateral, repaid -1.1000000000000081e-07 debt.
# Borrower 8 was liquidated! Seized 1.1000000000000085e-08 collateral, repaid 1.1000000000000085e-08 debt.
# Borrower 9 was liquidated! Seized -1.1000000000000081e-07 collateral, repaid -1.1000000000000081e-07 debt.
# Borrower 10 was liquidated! Seized 1.1000000000000085e-08 collateral, repaid 1.1000000000000085e-08 debt.
# Borrower 11 was liquidated! Seized 1.1000000000000085e-08 collateral, repaid 1.1000000000000085e-08 debt.
# Borrower 12 was liquidated! Seized 1.1000000000000085e-08 collateral, repaid 1.1000000000000085e-08 debt.
# Borrower 13 was liquidated! Seized -1.1000000000000081e-07 collateral, repaid -1.1000000000000081e-07 debt.
# Borrower 14 was liquidated! Seized 1.1000000000000085e-08 collateral, repaid 1.1000000000000085e-08 debt.
# Borrower 15 was liquidated! Seized 1.1000000000000085e-08 collateral, repaid 1.1000000000000085e-08 debt.
# Borrower 16 was liquidated! Seized -1.1000000000000081e-07 collateral, repaid -1.1000000000000081e-07 debt.
# Borrower 17 was liquidated! Seized -1.1000000000000081e-07 collateral, repaid -1.1000000000000081e-07 debt.
# Borrower 18 was liquidated! Seized -1.1000000000000081e-07 collateral, repaid -1.1000000000000081e-07 debt.
# Borrower 19 was liquidated! Seized 1.1000000000000085e-08 collateral, repaid 1.1000000000000085e-08 debt.
# Borrower 20 was liquidated! Seized -1.1000000000000081e-07 collateral, repaid -1.1000000000000081e-07 debt.
# Borrower 7 repaid 1.0856280971386059, remaining debt: 8.928008545577388
# Borrower 5 repaid 0.9925040923403491, remaining debt: 7.271231483731405
# Borrower 3 repaid 0.6721186021522068, remaining debt: 2.486369644774169
# Borrower 10 repaid 0.9777065847981692, remaining debt: 2.4303820596896184
# Borrower 8 repaid 0.4597780065650045, remaining debt: 1.5447790570836597
# Borrower 19 repaid 0.9120450941242936, remaining debt: 2.200449607885224
# Borrower 2 repaid 2.4164369464782802, remaining debt: 7.403745994942142
# Borrower 17 repaid 0.43709550993635177, remaining debt: 2.5431428981428343
# Borrower 16 repaid 0.6487612561486439, remaining debt: 1.6105296428661924
# Borrower 1 was liquidated! Seized 1.1000000000000085e-08 collateral, repaid 1.1000000000000085e-08 debt.
# Borrower 2 was liquidated! Seized 1.1000000000000085e-08 collateral, repaid 1.1000000000000085e-08 debt.
# Borrower 3 was liquidated! Seized -1.1000000000000098e-09 collateral, repaid -1.1000000000000098e-09 debt.
# Borrower 4 was liquidated! Seized 1.1000000000000085e-08 collateral, repaid 1.1000000000000085e-08 debt.
# Borrower 5 was liquidated! Seized 1.1000000000000085e-08 collateral, repaid 1.1000000000000085e-08 debt.
# Borrower 6 was liquidated! Seized 1.1000000000000085e-08 collateral, repaid 1.1000000000000085e-08 debt.
# Borrower 7 was liquidated! Seized 1.1000000000000085e-08 collateral, repaid 1.1000000000000085e-08 debt.
# Borrower 8 was liquidated! Seized -1.1000000000000098e-09 collateral, repaid -1.1000000000000098e-09 debt.
# Borrower 9 was liquidated! Seized 1.1000000000000085e-08 collateral, repaid 1.1000000000000085e-08 debt.
# Borrower 10 was liquidated! Seized -1.1000000000000098e-09 collateral, repaid -1.1000000000000098e-09 debt.
# Borrower 11 was liquidated! Seized -1.1000000000000098e-09 collateral, repaid -1.1000000000000098e-09 debt.
# Borrower 12 was liquidated! Seized -1.1000000000000098e-09 collateral, repaid -1.1000000000000098e-09 debt.
# Borrower 13 was liquidated! Seized 1.1000000000000085e-08 collateral, repaid 1.1000000000000085e-08 debt.
# Borrower 14 was liquidated! Seized -1.1000000000000098e-09 collateral, repaid -1.1000000000000098e-09 debt.
# Borrower 15 was liquidated! Seized -1.1000000000000098e-09 collateral, repaid -1.1000000000000098e-09 debt.
# Borrower 16 was liquidated! Seized 1.1000000000000085e-08 collateral, repaid 1.1000000000000085e-08 debt.
# Borrower 17 was liquidated! Seized 1.1000000000000085e-08 collateral, repaid 1.1000000000000085e-08 debt.
# Borrower 18 was liquidated! Seized 1.1000000000000085e-08 collateral, repaid 1.1000000000000085e-08 debt.
# Borrower 19 was liquidated! Seized -1.1000000000000098e-09 collateral, repaid -1.1000000000000098e-09 debt.
# Borrower 20 was liquidated! Seized 1.1000000000000085e-08 collateral, repaid 1.1000000000000085e-08 debt.
# Borrower 10 repaid 0.5933053947020256, remaining debt: 1.8370766660875928
# Borrower 12 repaid 0.5614744507508603, remaining debt: 1.7237745841599859
# Borrower 13 repaid 3.663414781454583, remaining debt: 12.078410403060133
# Borrower 20 repaid 1.1754136373817798, remaining debt: 4.64438266520866
# Borrower 4 repaid 0.9153875992881444, remaining debt: 4.130536135834984
# Borrower 1 was liquidated! Seized -1.1000000000000098e-09 collateral, repaid -1.1000000000000098e-09 debt.
# Borrower 2 was liquidated! Seized -1.1000000000000098e-09 collateral, repaid -1.1000000000000098e-09 debt.
# Borrower 3 was liquidated! Seized 1.1000000000000099e-10 collateral, repaid 1.1000000000000099e-10 debt.
# Borrower 4 was liquidated! Seized -1.1000000000000098e-09 collateral, repaid -1.1000000000000098e-09 debt.
# Borrower 5 was liquidated! Seized -1.1000000000000098e-09 collateral, repaid -1.1000000000000098e-09 debt.
# Borrower 6 was liquidated! Seized -1.1000000000000098e-09 collateral, repaid -1.1000000000000098e-09 debt.
# Borrower 7 was liquidated! Seized -1.1000000000000098e-09 collateral, repaid -1.1000000000000098e-09 debt.
# Borrower 8 was liquidated! Seized 1.1000000000000099e-10 collateral, repaid 1.1000000000000099e-10 debt.
# Borrower 9 was liquidated! Seized -1.1000000000000098e-09 collateral, repaid -1.1000000000000098e-09 debt.
# Borrower 10 was liquidated! Seized 1.1000000000000099e-10 collateral, repaid 1.1000000000000099e-10 debt.
# Borrower 11 was liquidated! Seized 1.1000000000000099e-10 collateral, repaid 1.1000000000000099e-10 debt.
# Borrower 12 was liquidated! Seized 1.1000000000000099e-10 collateral, repaid 1.1000000000000099e-10 debt.
# Borrower 13 was liquidated! Seized -1.1000000000000098e-09 collateral, repaid -1.1000000000000098e-09 debt.
# Borrower 14 was liquidated! Seized 1.1000000000000099e-10 collateral, repaid 1.1000000000000099e-10 debt.
# Borrower 15 was liquidated! Seized 1.1000000000000099e-10 collateral, repaid 1.1000000000000099e-10 debt.
# Borrower 16 was liquidated! Seized -1.1000000000000098e-09 collateral, repaid -1.1000000000000098e-09 debt.
# Borrower 17 was liquidated! Seized -1.1000000000000098e-09 collateral, repaid -1.1000000000000098e-09 debt.
# Borrower 18 was liquidated! Seized -1.1000000000000098e-09 collateral, repaid -1.1000000000000098e-09 debt.
# Borrower 19 was liquidated! Seized 1.1000000000000099e-10 collateral, repaid 1.1000000000000099e-10 debt.
# Borrower 20 was liquidated! Seized -1.1000000000000098e-09 collateral, repaid -1.1000000000000098e-09 debt.
# Borrower 19 repaid 0.5526296509068216, remaining debt: 1.6478199579684023
# Borrower 17 repaid 0.429159675092478, remaining debt: 2.113983213150356
# Borrower 15 repaid 0.48560822286585315, remaining debt: 1.8395319011313134
# Borrower 9 repaid 2.5183507349152396, remaining debt: 6.468453398460282
# Borrower 3 repaid 0.5783260123006778, remaining debt: 1.9080436334634912
# Borrower 6 repaid 1.3995377410146803, remaining debt: 6.377271007823095
# Borrower 4 repaid 0.9969946398232424, remaining debt: 3.133541497111742
# Borrower 20 repaid 0.5591366369805618, remaining debt: 4.085246029328098
# Borrower 14 repaid 0.8321598445181028, remaining debt: 2.6412879229424164
# Borrower 12 repaid 0.20557891557174585, remaining debt: 1.51819566847824
# Borrower 1 was liquidated! Seized 1.1000000000000099e-10 collateral, repaid 1.1000000000000099e-10 debt.
# Borrower 2 was liquidated! Seized 1.1000000000000099e-10 collateral, repaid 1.1000000000000099e-10 debt.
# Borrower 3 was liquidated! Seized -1.1000000000000106e-11 collateral, repaid -1.1000000000000106e-11 debt.
# Borrower 4 was liquidated! Seized 1.1000000000000099e-10 collateral, repaid 1.1000000000000099e-10 debt.
# Borrower 5 was liquidated! Seized 1.1000000000000099e-10 collateral, repaid 1.1000000000000099e-10 debt.
# Borrower 6 was liquidated! Seized 1.1000000000000099e-10 collateral, repaid 1.1000000000000099e-10 debt.
# Borrower 7 was liquidated! Seized 1.1000000000000099e-10 collateral, repaid 1.1000000000000099e-10 debt.
# Borrower 8 was liquidated! Seized -1.1000000000000106e-11 collateral, repaid -1.1000000000000106e-11 debt.
# Borrower 9 was liquidated! Seized 1.1000000000000099e-10 collateral, repaid 1.1000000000000099e-10 debt.
# Borrower 10 was liquidated! Seized -1.1000000000000106e-11 collateral, repaid -1.1000000000000106e-11 debt.
# Borrower 11 was liquidated! Seized -1.1000000000000106e-11 collateral, repaid -1.1000000000000106e-11 debt.
# Borrower 12 was liquidated! Seized -1.1000000000000106e-11 collateral, repaid -1.1000000000000106e-11 debt.
# Borrower 13 was liquidated! Seized 1.1000000000000099e-10 collateral, repaid 1.1000000000000099e-10 debt.
# Borrower 14 was liquidated! Seized -1.1000000000000106e-11 collateral, repaid -1.1000000000000106e-11 debt.
# Borrower 15 was liquidated! Seized -1.1000000000000106e-11 collateral, repaid -1.1000000000000106e-11 debt.
# Borrower 16 was liquidated! Seized 1.1000000000000099e-10 collateral, repaid 1.1000000000000099e-10 debt.
# Borrower 17 was liquidated! Seized 1.1000000000000099e-10 collateral, repaid 1.1000000000000099e-10 debt.
# Borrower 18 was liquidated! Seized 1.1000000000000099e-10 collateral, repaid 1.1000000000000099e-10 debt.
# Borrower 19 was liquidated! Seized -1.1000000000000106e-11 collateral, repaid -1.1000000000000106e-11 debt.
# Borrower 20 was liquidated! Seized 1.1000000000000099e-10 collateral, repaid 1.1000000000000099e-10 debt.
# Borrower 19 repaid 0.46456156359676454, remaining debt: 1.1832583943826378
# Borrower 13 repaid 1.4453558237696615, remaining debt: 10.633054580280472
# Borrower 5 repaid 1.1673770211667585, remaining debt: 6.103854452554647
# Borrower 11 repaid 0.5742315188961631, remaining debt: 3.544431978484376
# Borrower 3 repaid 0.2853664995777055, remaining debt: 1.6226771338967858
# Borrower 9 repaid 1.7480120149715253, remaining debt: 4.720441383378756
# Borrower 8 repaid 0.23932591764825994, remaining debt: 1.3054531404363998
# Borrower 16 repaid 0.3997320764808272, remaining debt: 1.2107975563753652
# Borrower 6 repaid 1.0049811333197596, remaining debt: 5.372289874393336
# Borrower 12 repaid 0.20273832405524841, remaining debt: 1.3154573444339916
# Borrower 17 repaid 0.2334258828931052, remaining debt: 1.880557330147251
# Borrower 2 repaid 1.116253058713261, remaining debt: 6.287492926218881
# Borrower 20 repaid 0.6743327737520587, remaining debt: 3.4109132554660393
# Borrower 1 was liquidated! Seized -1.1000000000000106e-11 collateral, repaid -1.1000000000000106e-11 debt.
# Borrower 2 was liquidated! Seized -1.1000000000000106e-11 collateral, repaid -1.1000000000000106e-11 debt.
# Borrower 3 was liquidated! Seized 1.1000000000000123e-12 collateral, repaid 1.1000000000000123e-12 debt.
# Borrower 4 was liquidated! Seized -1.1000000000000106e-11 collateral, repaid -1.1000000000000106e-11 debt.
# Borrower 5 was liquidated! Seized -1.1000000000000106e-11 collateral, repaid -1.1000000000000106e-11 debt.
# Borrower 6 was liquidated! Seized -1.1000000000000106e-11 collateral, repaid -1.1000000000000106e-11 debt.
# Borrower 7 was liquidated! Seized -1.1000000000000106e-11 collateral, repaid -1.1000000000000106e-11 debt.
# Borrower 8 was liquidated! Seized 1.1000000000000123e-12 collateral, repaid 1.1000000000000123e-12 debt.
# Borrower 9 was liquidated! Seized -1.1000000000000106e-11 collateral, repaid -1.1000000000000106e-11 debt.
# Borrower 10 was liquidated! Seized 1.1000000000000123e-12 collateral, repaid 1.1000000000000123e-12 debt.
# Borrower 11 was liquidated! Seized 1.1000000000000123e-12 collateral, repaid 1.1000000000000123e-12 debt.
# Borrower 12 was liquidated! Seized 1.1000000000000123e-12 collateral, repaid 1.1000000000000123e-12 debt.
# Borrower 13 was liquidated! Seized -1.1000000000000106e-11 collateral, repaid -1.1000000000000106e-11 debt.
# Borrower 14 was liquidated! Seized 1.1000000000000123e-12 collateral, repaid 1.1000000000000123e-12 debt.
# Borrower 15 was liquidated! Seized 1.1000000000000123e-12 collateral, repaid 1.1000000000000123e-12 debt.
# Borrower 16 was liquidated! Seized -1.1000000000000106e-11 collateral, repaid -1.1000000000000106e-11 debt.
# Borrower 17 was liquidated! Seized -1.1000000000000106e-11 collateral, repaid -1.1000000000000106e-11 debt.
# Borrower 18 was liquidated! Seized -1.1000000000000106e-11 collateral, repaid -1.1000000000000106e-11 debt.
# Borrower 19 was liquidated! Seized 1.1000000000000123e-12 collateral, repaid 1.1000000000000123e-12 debt.
# Borrower 20 was liquidated! Seized -1.1000000000000106e-11 collateral, repaid -1.1000000000000106e-11 debt.
# Borrower 4 repaid 0.46996410178509407, remaining debt: 2.663577395227648
# Borrower 11 repaid 0.5757508301435068, remaining debt: 2.968681148339769
# Borrower 15 repaid 0.5198015224551439, remaining debt: 1.3197303786860695
# Borrower 17 repaid 0.4562063066392743, remaining debt: 1.4243510235189767
# Borrower 6 repaid 0.7814768429426552, remaining debt: 4.590813031461681
# Borrower 16 repaid 0.31849651800643053, remaining debt: 0.8923010383799348
# Borrower 19 repaid 0.3117529107116781, remaining debt: 0.8715054836698597
# Borrower 9 repaid 0.7356217246765433, remaining debt: 3.984819658713213
# Borrower 5 repaid 1.2228683023888118, remaining debt: 4.8809861501768355
# Borrower 3 repaid 0.4238090771740734, remaining debt: 1.1988680567216123
# Borrower 2 repaid 1.3317516038327573, remaining debt: 4.955741322397124
# Borrower 12 repaid 0.3487628048076512, remaining debt: 0.9666945396252404
# Borrower 1 repaid 1.2185869852168465, remaining debt: 3.5607557702397608
# Borrower 18 repaid 0.907422754636242, remaining debt: 2.3021344628000313
# Borrower 1 was liquidated! Seized 1.1000000000000123e-12 collateral, repaid 1.1000000000000123e-12 debt.
# Borrower 2 was liquidated! Seized 1.1000000000000123e-12 collateral, repaid 1.1000000000000123e-12 debt.
# Borrower 3 was liquidated! Seized -1.1000000000000132e-13 collateral, repaid -1.1000000000000132e-13 debt.
# Borrower 4 was liquidated! Seized 1.1000000000000123e-12 collateral, repaid 1.1000000000000123e-12 debt.
# Borrower 5 was liquidated! Seized 1.1000000000000123e-12 collateral, repaid 1.1000000000000123e-12 debt.
# Borrower 6 was liquidated! Seized 1.1000000000000123e-12 collateral, repaid 1.1000000000000123e-12 debt.
# Borrower 7 was liquidated! Seized 1.1000000000000123e-12 collateral, repaid 1.1000000000000123e-12 debt.
# Borrower 8 was liquidated! Seized -1.1000000000000132e-13 collateral, repaid -1.1000000000000132e-13 debt.
# Borrower 9 was liquidated! Seized 1.1000000000000123e-12 collateral, repaid 1.1000000000000123e-12 debt.
# Borrower 10 was liquidated! Seized -1.1000000000000132e-13 collateral, repaid -1.1000000000000132e-13 debt.
# Borrower 11 was liquidated! Seized -1.1000000000000132e-13 collateral, repaid -1.1000000000000132e-13 debt.
# Borrower 12 was liquidated! Seized -1.1000000000000132e-13 collateral, repaid -1.1000000000000132e-13 debt.
# Borrower 13 was liquidated! Seized 1.1000000000000123e-12 collateral, repaid 1.1000000000000123e-12 debt.
# Borrower 14 was liquidated! Seized -1.1000000000000132e-13 collateral, repaid -1.1000000000000132e-13 debt.
# Borrower 15 was liquidated! Seized -1.1000000000000132e-13 collateral, repaid -1.1000000000000132e-13 debt.
# Borrower 16 was liquidated! Seized 1.1000000000000123e-12 collateral, repaid 1.1000000000000123e-12 debt.
# Borrower 17 was liquidated! Seized 1.1000000000000123e-12 collateral, repaid 1.1000000000000123e-12 debt.
# Borrower 18 was liquidated! Seized 1.1000000000000123e-12 collateral, repaid 1.1000000000000123e-12 debt.
# Borrower 19 was liquidated! Seized -1.1000000000000132e-13 collateral, repaid -1.1000000000000132e-13 debt.
# Borrower 20 was liquidated! Seized 1.1000000000000123e-12 collateral, repaid 1.1000000000000123e-12 debt.
# Borrower 1 repaid 0.9255419431502926, remaining debt: 2.6352138270883683
# Borrower 19 repaid 0.24985672628999037, remaining debt: 0.6216487573799794
# Borrower 8 repaid 0.35805748834455137, remaining debt: 0.9473956520908584
# Borrower 14 repaid 0.4038020449559481, remaining debt: 2.2374858779964786
# Borrower 2 repaid 0.9561418304705915, remaining debt: 3.9995994919254327
# Borrower 11 repaid 0.40984094080764366, remaining debt: 2.5588402075322354
# Borrower 12 repaid 0.17700482782493318, remaining debt: 0.7896897118004172
# Borrower 16 repaid 0.13178354906891118, remaining debt: 0.7605174893099236
# Borrower 1 was liquidated! Seized -1.1000000000000132e-13 collateral, repaid -1.1000000000000132e-13 debt.
# Borrower 2 was liquidated! Seized -1.1000000000000132e-13 collateral, repaid -1.1000000000000132e-13 debt.
# Borrower 3 was liquidated! Seized 1.1000000000000149e-14 collateral, repaid 1.1000000000000149e-14 debt.
# Borrower 4 was liquidated! Seized -1.1000000000000132e-13 collateral, repaid -1.1000000000000132e-13 debt.
# Borrower 5 was liquidated! Seized -1.1000000000000132e-13 collateral, repaid -1.1000000000000132e-13 debt.
# Borrower 6 was liquidated! Seized -1.1000000000000132e-13 collateral, repaid -1.1000000000000132e-13 debt.
# Borrower 7 was liquidated! Seized -1.1000000000000132e-13 collateral, repaid -1.1000000000000132e-13 debt.
# ...
# Borrower 5 was liquidated! Seized 1.1000000000000207e-20 collateral, repaid 1.1000000000000207e-20 debt.
# Borrower 6 was liquidated! Seized 1.1000000000000207e-20 collateral, repaid 1.1000000000000207e-20 debt.
# Borrower 7 was liquidated! Seized 1.1000000000000207e-20 collateral, repaid 1.1000000000000207e-20 debt.
# Borrower 8 was liquidated! Seized -1.1000000000000217e-21 collateral, repaid -1.1000000000000217e-21 debt.
# Borrower 9 was liquidated! Seized 1.1000000000000207e-20 collateral, repaid 1.1000000000000207e-20 debt.
# Borrower 10 was liquidated! Seized -1.1000000000000217e-21 collateral, repaid -1.1000000000000217e-21 debt.
# Borrower 11 was liquidated! Seized -1.1000000000000217e-21 collateral, repaid -1.1000000000000217e-21 debt.
# Borrower 12 was liquidated! Seized -1.1000000000000217e-21 collateral, repaid -1.1000000000000217e-21 debt.
# Borrower 13 was liquidated! Seized 1.1000000000000207e-20 collateral, repaid 1.1000000000000207e-20 debt.
# Borrower 14 was liquidated! Seized -1.1000000000000217e-21 collateral, repaid -1.1000000000000217e-21 debt.
# Borrower 15 was liquidated! Seized -1.1000000000000217e-21 collateral, repaid -1.1000000000000217e-21 debt.
# Borrower 16 was liquidated! Seized 1.1000000000000207e-20 collateral, repaid 1.1000000000000207e-20 debt.
# Borrower 17 was liquidated! Seized 1.1000000000000207e-20 collateral, repaid 1.1000000000000207e-20 debt.
# Borrower 18 was liquidated! Seized 1.1000000000000207e-20 collateral, repaid 1.1000000000000207e-20 debt.
# Borrower 19 was liquidated! Seized -1.1000000000000217e-21 collateral, repaid -1.1000000000000217e-21 debt.
# Borrower 20 was liquidated! Seized 1.1000000000000207e-20 collateral, repaid 1.1000000000000207e-20 debt.
# Borrower 8 repaid 0.19772385722648228, remaining debt: 0.6062115068665157
# Borrower 10 repaid 0.1297566677125812, remaining debt: 0.9657185388728513
# Borrower 7 repaid 2.1334059295537453, remaining debt: 5.141963537697206
# Borrower 15 repaid 0.0716755840892508, remaining debt: 0.44430027341718215
# Borrower 18 repaid 0.38103272830255885, remaining debt: 0.9100401788458597
# Borrower 12 repaid 0.0828116557758, remaining debt: 0.3719170814910868
# Borrower 11 repaid 0.26211421712866007, remaining debt: 0.9191274336203952
# Borrower 19 repaid 0.0406591547390307, remaining debt: 0.3253398340580049
# Borrower 5 repaid 0.43627710808031916, remaining debt: 2.031430045927771
# Borrower 13 repaid 1.2140516050825991, remaining debt: 3.1085734430091434
# Borrower 20 repaid 0.3626944017321958, remaining debt: 1.9668967774621597
# Borrower 1 was liquidated! Seized -1.1000000000000217e-21 collateral, repaid -1.1000000000000217e-21 debt.
# Borrower 2 was liquidated! Seized -1.1000000000000217e-21 collateral, repaid -1.1000000000000217e-21 debt.
# Borrower 3 was liquidated! Seized 1.1000000000000221e-22 collateral, repaid 1.1000000000000221e-22 debt.
# Borrower 4 was liquidated! Seized -1.1000000000000217e-21 collateral, repaid -1.1000000000000217e-21 debt.
# Borrower 5 was liquidated! Seized -1.1000000000000217e-21 collateral, repaid -1.1000000000000217e-21 debt.
# Borrower 6 was liquidated! Seized -1.1000000000000217e-21 collateral, repaid -1.1000000000000217e-21 debt.
# Borrower 7 was liquidated! Seized -1.1000000000000217e-21 collateral, repaid -1.1000000000000217e-21 debt.
# Borrower 8 was liquidated! Seized 1.1000000000000221e-22 collateral, repaid 1.1000000000000221e-22 debt.
# Borrower 9 was liquidated! Seized -1.1000000000000217e-21 collateral, repaid -1.1000000000000217e-21 debt.
# Borrower 10 was liquidated! Seized 1.1000000000000221e-22 collateral, repaid 1.1000000000000221e-22 debt.
# Borrower 11 was liquidated! Seized 1.1000000000000221e-22 collateral, repaid 1.1000000000000221e-22 debt.
# Borrower 12 was liquidated! Seized 1.1000000000000221e-22 collateral, repaid 1.1000000000000221e-22 debt.
# Borrower 13 was liquidated! Seized -1.1000000000000217e-21 collateral, repaid -1.1000000000000217e-21 debt.
# Borrower 14 was liquidated! Seized 1.1000000000000221e-22 collateral, repaid 1.1000000000000221e-22 debt.
# Borrower 15 was liquidated! Seized 1.1000000000000221e-22 collateral, repaid 1.1000000000000221e-22 debt.
# Borrower 16 was liquidated! Seized -1.1000000000000217e-21 collateral, repaid -1.1000000000000217e-21 debt.
# Borrower 17 was liquidated! Seized -1.1000000000000217e-21 collateral, repaid -1.1000000000000217e-21 debt.
# Borrower 18 was liquidated! Seized -1.1000000000000217e-21 collateral, repaid -1.1000000000000217e-21 debt.
# Borrower 19 was liquidated! Seized 1.1000000000000221e-22 collateral, repaid 1.1000000000000221e-22 debt.
# Borrower 20 was liquidated! Seized -1.1000000000000217e-21 collateral, repaid -1.1000000000000217e-21 debt.
# Borrower 13 repaid 0.5920925117441175, remaining debt: 2.516480931265026
# Borrower 8 repaid 0.1240071576720411, remaining debt: 0.48220434919447464
# Borrower 18 repaid 0.10308375684938544, remaining debt: 0.8069564219964743
# Borrower 7 repaid 1.4156241223329153, remaining debt: 3.726339415364291
# Borrower 10 repaid 0.14133276775246642, remaining debt: 0.8243857711203849
# Borrower 11 repaid 0.09283197373597052, remaining debt: 0.8262954598844247
# Borrower 20 repaid 0.3974532588510769, remaining debt: 1.5694435186110829
# Borrower 14 repaid 0.14946296086519734, remaining debt: 0.38091818564957497
# Borrower 1 was liquidated! Seized 1.1000000000000221e-22 collateral, repaid 1.1000000000000221e-22 debt.
# Borrower 2 was liquidated! Seized 1.1000000000000221e-22 collateral, repaid 1.1000000000000221e-22 debt.
# Borrower 3 was liquidated! Seized -1.1000000000000232e-23 collateral, repaid -1.1000000000000232e-23 debt.
# Borrower 4 was liquidated! Seized 1.1000000000000221e-22 collateral, repaid 1.1000000000000221e-22 debt.
# Borrower 5 was liquidated! Seized 1.1000000000000221e-22 collateral, repaid 1.1000000000000221e-22 debt.
# Borrower 6 was liquidated! Seized 1.1000000000000221e-22 collateral, repaid 1.1000000000000221e-22 debt.
# Borrower 7 was liquidated! Seized 1.1000000000000221e-22 collateral, repaid 1.1000000000000221e-22 debt.
# Borrower 8 was liquidated! Seized -1.1000000000000232e-23 collateral, repaid -1.1000000000000232e-23 debt.
# Borrower 9 was liquidated! Seized 1.1000000000000221e-22 collateral, repaid 1.1000000000000221e-22 debt.
# Borrower 10 was liquidated! Seized -1.1000000000000232e-23 collateral, repaid -1.1000000000000232e-23 debt.
# Borrower 11 was liquidated! Seized -1.1000000000000232e-23 collateral, repaid -1.1000000000000232e-23 debt.
# Borrower 12 was liquidated! Seized -1.1000000000000232e-23 collateral, repaid -1.1000000000000232e-23 debt.
# Borrower 13 was liquidated! Seized 1.1000000000000221e-22 collateral, repaid 1.1000000000000221e-22 debt.
# Borrower 14 was liquidated! Seized -1.1000000000000232e-23 collateral, repaid -1.1000000000000232e-23 debt.
# Borrower 15 was liquidated! Seized -1.1000000000000232e-23 collateral, repaid -1.1000000000000232e-23 debt.
# Borrower 16 was liquidated! Seized 1.1000000000000221e-22 collateral, repaid 1.1000000000000221e-22 debt.
# Borrower 17 was liquidated! Seized 1.1000000000000221e-22 collateral, repaid 1.1000000000000221e-22 debt.
# Borrower 18 was liquidated! Seized 1.1000000000000221e-22 collateral, repaid 1.1000000000000221e-22 debt.
# Borrower 19 was liquidated! Seized -1.1000000000000232e-23 collateral, repaid -1.1000000000000232e-23 debt.
# Borrower 20 was liquidated! Seized 1.1000000000000221e-22 collateral, repaid 1.1000000000000221e-22 debt.
# Borrower 8 repaid 0.06460422121725651, remaining debt: 0.4176001279772181
# Borrower 18 repaid 0.1568514346492077, remaining debt: 0.6501049873472666
# Borrower 6 repaid 0.25708649643018644, remaining debt: 1.077294380493081
# Borrower 13 repaid 0.6035923095442189, remaining debt: 1.912888621720807
# Borrower 9 repaid 0.4445517607802526, remaining debt: 1.0986594717459033
# Borrower 19 repaid 0.07894875478551397, remaining debt: 0.2463910792724909
# Borrower 4 repaid 0.19584149009071353, remaining debt: 0.8852992379146438
# Borrower 1 was liquidated! Seized -1.1000000000000232e-23 collateral, repaid -1.1000000000000232e-23 debt.
# Borrower 2 was liquidated! Seized -1.1000000000000232e-23 collateral, repaid -1.1000000000000232e-23 debt.
# Borrower 3 was liquidated! Seized 1.1000000000000244e-24 collateral, repaid 1.1000000000000244e-24 debt.
# Borrower 4 was liquidated! Seized -1.1000000000000232e-23 collateral, repaid -1.1000000000000232e-23 debt.
# Borrower 5 was liquidated! Seized -1.1000000000000232e-23 collateral, repaid -1.1000000000000232e-23 debt.
# Borrower 6 was liquidated! Seized -1.1000000000000232e-23 collateral, repaid -1.1000000000000232e-23 debt.
# Borrower 7 was liquidated! Seized -1.1000000000000232e-23 collateral, repaid -1.1000000000000232e-23 debt.
# Borrower 8 was liquidated! Seized 1.1000000000000244e-24 collateral, repaid 1.1000000000000244e-24 debt.
# Borrower 9 was liquidated! Seized -1.1000000000000232e-23 collateral, repaid -1.1000000000000232e-23 debt.
# Borrower 10 was liquidated! Seized 1.1000000000000244e-24 collateral, repaid 1.1000000000000244e-24 debt.
# Borrower 11 was liquidated! Seized 1.1000000000000244e-24 collateral, repaid 1.1000000000000244e-24 debt.
# Borrower 12 was liquidated! Seized 1.1000000000000244e-24 collateral, repaid 1.1000000000000244e-24 debt.
# Borrower 13 was liquidated! Seized -1.1000000000000232e-23 collateral, repaid -1.1000000000000232e-23 debt.
# Borrower 14 was liquidated! Seized 1.1000000000000244e-24 collateral, repaid 1.1000000000000244e-24 debt.
# Borrower 15 was liquidated! Seized 1.1000000000000244e-24 collateral, repaid 1.1000000000000244e-24 debt.
# Borrower 16 was liquidated! Seized -1.1000000000000232e-23 collateral, repaid -1.1000000000000232e-23 debt.
# Borrower 17 was liquidated! Seized -1.1000000000000232e-23 collateral, repaid -1.1000000000000232e-23 debt.
# Borrower 18 was liquidated! Seized -1.1000000000000232e-23 collateral, repaid -1.1000000000000232e-23 debt.
# Borrower 19 was liquidated! Seized 1.1000000000000244e-24 collateral, repaid 1.1000000000000244e-24 debt.
# Borrower 20 was liquidated! Seized -1.1000000000000232e-23 collateral, repaid -1.1000000000000232e-23 debt.
# Borrower 4 repaid 0.20103167711053352, remaining debt: 0.6842675608041103
# Borrower 10 repaid 0.12051854115259698, remaining debt: 0.7038672299677879
# Borrower 15 repaid 0.0962033489408081, remaining debt: 0.348096924476374
# Borrower 20 repaid 0.4677146689704028, remaining debt: 1.10172884964068
# Borrower 19 repaid 0.056436144239075704, remaining debt: 0.1899549350334152
# Borrower 12 repaid 0.04932649835091578, remaining debt: 0.322590583140171
# Borrower 14 repaid 0.10065888800061175, remaining debt: 0.28025929764896323
# Borrower 7 repaid 0.8355062017370934, remaining debt: 2.8908332136271975
# Borrower 1 repaid 0.2074824355924898, remaining debt: 0.8505692684739286
# Borrower 8 repaid 0.09544580164177745, remaining debt: 0.32215432633544067
# Borrower 11 repaid 0.18898098141637756, remaining debt: 0.6373144784680471
# Borrower 1 was liquidated! Seized 1.1000000000000244e-24 collateral, repaid 1.1000000000000244e-24 debt.
# Borrower 2 was liquidated! Seized 1.1000000000000244e-24 collateral, repaid 1.1000000000000244e-24 debt.
# Borrower 3 was liquidated! Seized -1.1000000000000254e-25 collateral, repaid -1.1000000000000254e-25 debt.
# Borrower 4 was liquidated! Seized 1.1000000000000244e-24 collateral, repaid 1.1000000000000244e-24 debt.
# Borrower 5 was liquidated! Seized 1.1000000000000244e-24 collateral, repaid 1.1000000000000244e-24 debt.
# Borrower 6 was liquidated! Seized 1.1000000000000244e-24 collateral, repaid 1.1000000000000244e-24 debt.
# Borrower 7 was liquidated! Seized 1.1000000000000244e-24 collateral, repaid 1.1000000000000244e-24 debt.
# Borrower 8 was liquidated! Seized -1.1000000000000254e-25 collateral, repaid -1.1000000000000254e-25 debt.
# Borrower 9 was liquidated! Seized 1.1000000000000244e-24 collateral, repaid 1.1000000000000244e-24 debt.
# Borrower 10 was liquidated! Seized -1.1000000000000254e-25 collateral, repaid -1.1000000000000254e-25 debt.
# Borrower 11 was liquidated! Seized -1.1000000000000254e-25 collateral, repaid -1.1000000000000254e-25 debt.
# Borrower 12 was liquidated! Seized -1.1000000000000254e-25 collateral, repaid -1.1000000000000254e-25 debt.
# Borrower 13 was liquidated! Seized 1.1000000000000244e-24 collateral, repaid 1.1000000000000244e-24 debt.
# Borrower 14 was liquidated! Seized -1.1000000000000254e-25 collateral, repaid -1.1000000000000254e-25 debt.
# Borrower 15 was liquidated! Seized -1.1000000000000254e-25 collateral, repaid -1.1000000000000254e-25 debt.
# Borrower 16 was liquidated! Seized 1.1000000000000244e-24 collateral, repaid 1.1000000000000244e-24 debt.
# Borrower 17 was liquidated! Seized 1.1000000000000244e-24 collateral, repaid 1.1000000000000244e-24 debt.
# Borrower 18 was liquidated! Seized 1.1000000000000244e-24 collateral, repaid 1.1000000000000244e-24 debt.
# Borrower 19 was liquidated! Seized -1.1000000000000254e-25 collateral, repaid -1.1000000000000254e-25 debt.
# Borrower 20 was liquidated! Seized 1.1000000000000244e-24 collateral, repaid 1.1000000000000244e-24 debt.
# Borrower 14 repaid 0.07022718410574444, remaining debt: 0.2100321135432188
# Borrower 1 repaid 0.21167981053742305, remaining debt: 0.6388894579365055
# Borrower 10 repaid 0.1263599726166669, remaining debt: 0.5775072573511211
# Borrower 2 repaid 0.3646021042057225, remaining debt: 0.9689959025763982
# Borrower 12 repaid 0.034546060984804734, remaining debt: 0.2880445221553663
# Borrower 16 repaid 0.056712555291152586, remaining debt: 0.29889827555646414
# Borrower 3 repaid 0.07310880811950374, remaining debt: 0.43955004385012997
# Borrower 6 repaid 0.3182193498839264, remaining debt: 0.7590750306091546
# Borrower 20 repaid 0.16419324273249986, remaining debt: 0.9375356069081802
# Borrower 4 repaid 0.18932907395285697, remaining debt: 0.49493848685125336
# Borrower 8 repaid 0.059818925908213215, remaining debt: 0.26233540042722747
# Borrower 1 was liquidated! Seized -1.1000000000000254e-25 collateral, repaid -1.1000000000000254e-25 debt.
# Borrower 2 was liquidated! Seized -1.1000000000000254e-25 collateral, repaid -1.1000000000000254e-25 debt.
# Borrower 3 was liquidated! Seized 1.1000000000000273e-26 collateral, repaid 1.1000000000000273e-26 debt.
# Borrower 4 was liquidated! Seized -1.1000000000000254e-25 collateral, repaid -1.1000000000000254e-25 debt.
# Borrower 5 was liquidated! Seized -1.1000000000000254e-25 collateral, repaid -1.1000000000000254e-25 debt.
# Borrower 6 was liquidated! Seized -1.1000000000000254e-25 collateral, repaid -1.1000000000000254e-25 debt.
# Borrower 7 was liquidated! Seized -1.1000000000000254e-25 collateral, repaid -1.1000000000000254e-25 debt.
# Borrower 8 was liquidated! Seized 1.1000000000000273e-26 collateral, repaid 1.1000000000000273e-26 debt.
# Borrower 9 was liquidated! Seized -1.1000000000000254e-25 collateral, repaid -1.1000000000000254e-25 debt.
# Borrower 10 was liquidated! Seized 1.1000000000000273e-26 collateral, repaid 1.1000000000000273e-26 debt.
# Borrower 11 was liquidated! Seized 1.1000000000000273e-26 collateral, repaid 1.1000000000000273e-26 debt.
# Borrower 12 was liquidated! Seized 1.1000000000000273e-26 collateral, repaid 1.1000000000000273e-26 debt.
# Borrower 13 was liquidated! Seized -1.1000000000000254e-25 collateral, repaid -1.1000000000000254e-25 debt.
# Borrower 14 was liquidated! Seized 1.1000000000000273e-26 collateral, repaid 1.1000000000000273e-26 debt.
# Borrower 15 was liquidated! Seized 1.1000000000000273e-26 collateral, repaid 1.1000000000000273e-26 debt.
# Borrower 16 was liquidated! Seized -1.1000000000000254e-25 collateral, repaid -1.1000000000000254e-25 debt.
# Borrower 17 was liquidated! Seized -1.1000000000000254e-25 collateral, repaid -1.1000000000000254e-25 debt.
# Borrower 18 was liquidated! Seized -1.1000000000000254e-25 collateral, repaid -1.1000000000000254e-25 debt.
# Borrower 19 was liquidated! Seized 1.1000000000000273e-26 collateral, repaid 1.1000000000000273e-26 debt.
# Borrower 20 was liquidated! Seized -1.1000000000000254e-25 collateral, repaid -1.1000000000000254e-25 debt.

# %%
model.datacollector.get_model_vars_dataframe()
# Out:
#     Total Liquidity  Total Borrowed  Utilization Rate  Interest Rate
# 0       1000.000000        0.000000          0.000000       0.020000
# 1      16000.000000      895.319111          0.055957       0.020560
# 2      16745.248776      882.418807          0.052697       0.020527
# 3      17922.462796      182.096792          0.010160       0.020102
# 4      17799.262796      276.714738          0.015546       0.020155
# 5      17811.582796      233.302281          0.013098       0.020131
# 6      17810.350796      224.794576          0.012622       0.020126
# 7      17810.473996      188.103910          0.010561       0.020106
# 8      17810.461676      180.335586          0.010125       0.020101
# 9      17810.462908      159.273135          0.008943       0.020089
# 10     17810.462785      140.035935          0.007863       0.020079
# 11     17810.462798      126.209728          0.007086       0.020071
# 12     17810.462796      108.583272          0.006097       0.020061
# 13     17810.462796       99.981197          0.005614       0.020056
# 14     17810.462796       93.072202          0.005226       0.020052
# 15     17810.462796       84.514719          0.004745       0.020047
# 16     17810.462796       74.959026          0.004209       0.020042
# 17     17810.462796       65.336754          0.003668       0.020037
# 18     17810.462796       61.724724          0.003466       0.020035
# 19     17810.462796       55.246557          0.003102       0.020031
# 20     17810.462796       50.377856          0.002829       0.020028
# 21     17810.462796       43.557335          0.002446       0.020024
# 22     17810.462796       38.770823          0.002177       0.020022
# 23     17810.462796       35.886683          0.002015       0.020020
# 24     17810.462796       32.529818          0.001826       0.020018
# 25     17810.462796       30.649136          0.001721       0.020017
# 26     17810.462796       25.336933          0.001423       0.020014
# 27     17810.462796       22.321045          0.001253       0.020013
# 28     17810.462796       20.519568          0.001152       0.020012
# 29     17810.462796       18.100263          0.001016       0.020010
